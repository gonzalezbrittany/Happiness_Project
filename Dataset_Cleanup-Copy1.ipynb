# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

# %%
# Import dataset
# The happiness data files 2021 and trending
happiness_t_file= "Data/world-happiness-report-clean.csv" #checked
happiness_file = "Data/world-happiness-report-2021-clean.csv" #checked
covid_data = "Data/kaggle-covid/worldometer_data_test.csv" #checked
screen_time = "Data/Clean_Average_Screen_Time_per_Country_2021_clean.csv" #checked
population_density = "Data/Country_Population_Land_Area_Density_clean.csv" #checked
alcohol_consumption = "Data/alcohol_consumption_bycountry-clean.csv" #checked
meat_consumption = "Data/Meat_consumption_clean.csv" #checked
median_age = "Data/Median_age_clean.csv" #checked
suicide_rate = "Data/Suicide_rate_clean.csv" #checked

# %%
# Convert datasets to dataframes
happiness_t_file_df = pd.read_csv(happiness_t_file)
happiness_file_2021_df = pd.read_csv(happiness_file)
covid_data_df = pd.read_csv(covid_data)
screen_time_df = pd.read_csv(screen_time)
population_density_df = pd.read_csv(population_density)
alcohol_consumption_df = pd.read_csv(alcohol_consumption)
meat_consumption_df = pd.read_csv(meat_consumption)
median_age_df = pd.read_csv(median_age)
suicide_rate_df = pd.read_csv(suicide_rate)

# %% [markdown]
# # Clean happiness_t_file_df

# %%
happiness_t_file_df.head()
# Out:
#   Country_Name  year Regional_Indicator  Ladder_Score  Logged_GDP_per_Capita  \
# 0  Afghanistan  2008         South Asia         3.724                  7.370
# 1  Afghanistan  2009         South Asia         4.402                  7.540
# 2  Afghanistan  2010         South Asia         4.758                  7.647
# 3  Afghanistan  2011         South Asia         3.832                  7.620
# 4  Afghanistan  2012         South Asia         3.783                  7.705
#
#    Social support  Healthy_Life_Expectancy  Freedom_to_make_life_choices  \
# 0           0.451                    50.80                         0.718
# 1           0.552                    51.20                         0.679
# 2           0.539                    51.60                         0.600
# 3           0.521                    51.92                         0.496
# 4           0.521                    52.24                         0.531
#
# ...

# %%
#rename columns in happiness_t_file dataframe
happiness_t_file_df.rename(columns = {'Country name': 'Country_Name'}, inplace = True)
happiness_t_file_df.rename(columns = {'Regional indicator': 'Regional_Indicator'}, inplace = True)
happiness_t_file_df.rename(columns = {'Life Ladder': 'Ladder_Score'}, inplace = True)
happiness_t_file_df.rename(columns = {'Log GDP per capita': 'Logged_GDP_per_Capita'}, inplace = True)
happiness_t_file_df.rename(columns = {'Healthy life expectancy at birth': 'Healthy_Life_Expectancy'}, inplace = True)
happiness_t_file_df.rename(columns = {'Freedom to make life choices': 'Freedom_to_make_life_choices'}, inplace = True)
happiness_t_file_df.rename(columns = {'Perceptions of corruption': 'Perceptions_of_corruption'}, inplace = True)
happiness_t_file_df.rename(columns = {'Positive affect': 'Positive_Affect'}, inplace = True)
happiness_t_file_df.rename(columns = {'Negative affect': 'Negative_affect'}, inplace = True)

# %%
happiness_t_file_df.head()
# Out:
#   Country_Name  year Regional_Indicator  Ladder_Score  Logged_GDP_per_Capita  \
# 0  Afghanistan  2008         South Asia         3.724                  7.370
# 1  Afghanistan  2009         South Asia         4.402                  7.540
# 2  Afghanistan  2010         South Asia         4.758                  7.647
# 3  Afghanistan  2011         South Asia         3.832                  7.620
# 4  Afghanistan  2012         South Asia         3.783                  7.705
#
#    Social support  Healthy_Life_Expectancy  Freedom_to_make_life_choices  \
# 0           0.451                    50.80                         0.718
# 1           0.552                    51.20                         0.679
# 2           0.539                    51.60                         0.600
# 3           0.521                    51.92                         0.496
# 4           0.521                    52.24                         0.531
#
# ...

# %%
# View column names in happiness_t_file_df
list(happiness_t_file_df)
# Out:
# ['Country_Name',
#  'year',
#  'Regional_Indicator',
#  'Ladder_Score',
#  'Logged_GDP_per_Capita',
#  'Social support',
#  'Healthy_Life_Expectancy',
#  'Freedom_to_make_life_choices',
#  'Generosity',
#  'Perceptions_of_corruption',
#  'Positive_Affect',
#  'Negative_affect']

# %% [markdown]
# # Clean happiness_file_2021_df dataframe

# %%
happiness_file_2021_df.head()
# Out:
#   Country_Name  year Regional_Indicator  Ladder_Score  \
# 0      Finland  2021     Western Europe         7.842
# 1      Denmark  2021     Western Europe         7.620
# 2  Switzerland  2021     Western Europe         7.571
# 3      Iceland  2021     Western Europe         7.554
# 4  Netherlands  2021     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  ...  \
# 0                 10.775           0.954                     72.0  ...
# 1                 10.933           0.954                     72.7  ...
# ...

# %%
# rename column names
happiness_file_2021_df.rename(columns = {'Country name': 'Country_Name'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Regional indicator': 'Regional_Indicator'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Ladder score': 'Ladder_Score'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Logged GDP per capita': 'Logged_GDP_per_Capita'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Healthy life expectancy': 'Healthy_Life_Expectancy'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Freedom to make life choices': 'Freedom_to_make_life_choices'}, inplace = True)
happiness_file_2021_df.rename(columns = {'Perceptions of corruption': 'Perceptions_of_corruption'}, inplace = True)

# %%
happiness_file_2021_df.head()
# Out:
#   Country_Name  year Regional_Indicator  Ladder_Score  \
# 0      Finland  2021     Western Europe         7.842
# 1      Denmark  2021     Western Europe         7.620
# 2  Switzerland  2021     Western Europe         7.571
# 3      Iceland  2021     Western Europe         7.554
# 4  Netherlands  2021     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  ...  \
# 0                 10.775           0.954                     72.0  ...
# 1                 10.933           0.954                     72.7  ...
# ...

# %%
#View all column names
list(happiness_file_2021_df)
# Out:
# ['Country_Name',
#  'year',
#  'Regional_Indicator',
#  'Ladder_Score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged_GDP_per_Capita',
#  'Social support',
#  'Healthy_Life_Expectancy',
#  'Freedom_to_make_life_choices',
#  'Generosity',
#  'Perceptions_of_corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual']

# %%
# combine both happiness scores datasets
happiness_score_df = happiness_t_file_df.append(happiness_file_2021_df)
# Out:
# C:\Users\Brittany\AppData\Local\Temp\ipykernel_22104\2024588666.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   happiness_score_df = happiness_t_file_df.append(happiness_file_2021_df)

# %%
# view total null values for columns
happiness_score_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                             0
# Regional_Indicator                               0
# Ladder_Score                                     0
# Logged_GDP_per_Capita                           36
# Social support                                  13
# Healthy_Life_Expectancy                         55
# Freedom_to_make_life_choices                    32
# Generosity                                      89
# Perceptions_of_corruption                      110
# Positive_Affect                                171
# Negative_affect                                165
# Standard error of ladder score                1949
# upperwhisker                                  1949
# lowerwhisker                                  1949
# Ladder score in Dystopia                      1949
# Explained by: Log GDP per capita              1949
# Explained by: Social support                  1949
# ...

# %% [markdown]
# # Clean alcohol_consumption_df dataset

# %%
alcohol_consumption_df.head()
# Out:
#   Country_Name  year                  Regional_Indicator  \
# 0       Latvia  2019          Central and Eastern Europe
# 1      Moldova  2019  Commonwealth of Independent States
# 2      Germany  2019                      Western Europe
# 3    Lithuania  2019          Central and Eastern Europe
# 4      Ireland  2019                      Western Europe
#
#    alcohol_consumption_both_gender  alcohol_consumption_male  \
# 0                            13.19                     21.61
# 1                            12.85                     20.61
# 2                            12.79                     19.71
# 3                            12.78                     20.60
# 4                            12.75                     19.38
#
#    alcohol_consumption_female
# 0                        6.31
# 1                        5.89
# 2                        6.15
# 3                        6.30
# 4                        6.34

# %%
#rename columns
alcohol_consumption_df.rename(columns = {'both': 'alcohol_consumption_both_gender'}, inplace = True)
alcohol_consumption_df.rename(columns = {'male': 'alcohol_consumption_male'}, inplace = True)
alcohol_consumption_df.rename(columns = {'female': 'alcohol_consumption_female'}, inplace = True)

# %%
#drop unwanted columns 
alcohol_consumption_df = alcohol_consumption_df.drop(columns="year")
alcohol_consumption_df = alcohol_consumption_df.drop(columns="Regional_Indicator")
alcohol_consumption_df.head()
# Out:
#   Country_Name  alcohol_consumption_both_gender  alcohol_consumption_male  \
# 0       Latvia                            13.19                     21.61
# 1      Moldova                            12.85                     20.61
# 2      Germany                            12.79                     19.71
# 3    Lithuania                            12.78                     20.60
# 4      Ireland                            12.75                     19.38
#
#    alcohol_consumption_female
# 0                        6.31
# 1                        5.89
# 2                        6.15
# 3                        6.30
# 4                        6.34

# %%
alcohol_consumption_df.head()
# Out:
#   Country_Name  alcohol_consumption_both_gender  alcohol_consumption_male  \
# 0       Latvia                            13.19                     21.61
# 1      Moldova                            12.85                     20.61
# 2      Germany                            12.79                     19.71
# 3    Lithuania                            12.78                     20.60
# 4      Ireland                            12.75                     19.38
#
#    alcohol_consumption_female
# 0                        6.31
# 1                        5.89
# 2                        6.15
# 3                        6.30
# 4                        6.34

# %%
happiness_scores_alchohol = pd.merge(happiness_score_df,alcohol_consumption_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol.head(100)
# Out:
#    Country_Name    year Regional_Indicator  Ladder_Score  \
# 0   Afghanistan  2008.0         South Asia         3.724
# 1   Afghanistan  2009.0         South Asia         4.402
# 2   Afghanistan  2010.0         South Asia         4.758
# 3   Afghanistan  2011.0         South Asia         3.832
# 4   Afghanistan  2012.0         South Asia         3.783
# ..          ...     ...                ...           ...
# 95      Austria  2017.0     Western Europe         7.294
# 96      Austria  2018.0     Western Europe         7.396
# 97      Austria  2019.0     Western Europe         7.195
# 98      Austria  2020.0     Western Europe         7.213
# 99      Austria  2021.0     Western Europe         7.268
#
#     Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                   7.370           0.451                    50.80
# 1                   7.540           0.552                    51.20
# 2                   7.647           0.539                    51.60
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol.isna().sum()
# Out:
# Country_Name                                     0
# year                                            30
# Regional_Indicator                              30
# Ladder_Score                                    30
# Logged_GDP_per_Capita                           66
# Social support                                  43
# Healthy_Life_Expectancy                         85
# Freedom_to_make_life_choices                    62
# Generosity                                     119
# Perceptions_of_corruption                      140
# Positive_Affect                                201
# Negative_affect                                195
# Standard error of ladder score                1979
# upperwhisker                                  1979
# lowerwhisker                                  1979
# Ladder score in Dystopia                      1979
# Explained by: Log GDP per capita              1979
# Explained by: Social support                  1979
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol)
# Out:
# 2128

# %%
#View rows that have non-NA values for for aclohol to ensure join worked correctly 
happiness_scores_alchohol[~happiness_scores_alchohol['alcohol_consumption_both_gender'].isnull()].head(50)
# Out:
#    Country_Name    year            Regional_Indicator  Ladder_Score  \
# 0   Afghanistan  2008.0                    South Asia         3.724
# 1   Afghanistan  2009.0                    South Asia         4.402
# 2   Afghanistan  2010.0                    South Asia         4.758
# 3   Afghanistan  2011.0                    South Asia         3.832
# 4   Afghanistan  2012.0                    South Asia         3.783
# 5   Afghanistan  2013.0                    South Asia         3.572
# 6   Afghanistan  2014.0                    South Asia         3.131
# 7   Afghanistan  2015.0                    South Asia         3.983
# 8   Afghanistan  2016.0                    South Asia         4.220
# 9   Afghanistan  2017.0                    South Asia         2.662
# 10  Afghanistan  2018.0                    South Asia         2.694
# 11  Afghanistan  2019.0                    South Asia         2.375
# 12  Afghanistan  2021.0                    South Asia         2.523
# ...

# %% [markdown]
# # Clean covid_data_df dataset

# %%
covid_data_df.head()
# Out:
#    Country name  year      Continent    Population  TotalCases  NewCases  \
# 0           USA  2020  North America  3.311981e+08     5032179       NaN
# 1        Brazil  2020  South America  2.127107e+08     2917562       NaN
# 2         India  2020           Asia  1.381345e+09     2025409       NaN
# 3        Russia  2020         Europe  1.459409e+08      871894       NaN
# 4  South Africa  2020         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
#View all column names
list(covid_data_df)
# Out:
# ['Country name',
#  'year',
#  'Continent',
#  'Population',
#  'TotalCases',
#  'NewCases',
#  'TotalDeaths',
#  'NewDeaths',
#  'TotalRecovered',
#  'NewRecovered',
#  'ActiveCases',
#  'Serious,Critical',
#  'Tot Cases/1M pop',
#  'Deaths/1M pop',
#  'TotalTests',
#  'Tests/1M pop',
#  'WHO Region']

# %%
#rename columns
covid_data_df.rename(columns = {'Country name': 'Country_Name'}, inplace = True)
covid_data_df.rename(columns = {'Continent': 'Regional_Indicator'}, inplace = True)
covid_data_df.rename(columns = {'TotalCases': 'COVID_TotalCases'}, inplace = True)
covid_data_df.rename(columns = {'NewCases': 'COVID_NewCases'}, inplace = True)
covid_data_df.rename(columns = {'TotalDeaths': 'COVID_TotalDeaths'}, inplace = True)
covid_data_df.rename(columns = {'NewDeaths': 'COVID_NewDeaths'}, inplace = True)
covid_data_df.rename(columns = {'TotalRecovered': 'COVID_TotalRecovered'}, inplace = True)
covid_data_df.rename(columns = {'NewRecovered': 'COVID_NewRecovered'}, inplace = True)
covid_data_df.rename(columns = {'ActiveCases': 'COVID_ActiveCases'}, inplace = True)
covid_data_df.rename(columns = {'Serious,Critical': 'COVID_Serious/Critical'}, inplace = True)
covid_data_df.rename(columns = {'Tot Cases/1M pop': 'COVID_Tot Cases/1M pop'}, inplace = True)
covid_data_df.rename(columns = {'Deaths/1M pop': 'COVID_Deaths/1M pop'}, inplace = True)
covid_data_df.rename(columns = {'TotalTests': 'COVID_TotalTests'}, inplace = True)
covid_data_df.rename(columns = {'Tests/1M pop': 'COVID_Tests/1M pop'}, inplace = True)

# %%
#drop unwanted columns 
covid_data_df = covid_data_df.drop(columns="year")
covid_data_df = covid_data_df.drop(columns="Regional_Indicator")
covid_data_df.head()
# Out:
#    Country_Name    Population  COVID_TotalCases  COVID_NewCases  \
# 0           USA  3.311981e+08           5032179             NaN
# 1        Brazil  2.127107e+08           2917562             NaN
# 2         India  1.381345e+09           2025409             NaN
# 3        Russia  1.459409e+08            871894             NaN
# 4  South Africa  5.938157e+07            538184             NaN
#
#    COVID_TotalDeaths  COVID_NewDeaths  COVID_TotalRecovered  \
# 0           162804.0              NaN             2576668.0
# 1            98644.0              NaN             2047660.0
# 2            41638.0              NaN             1377384.0
# 3            14606.0              NaN              676357.0
# 4             9604.0              NaN              387316.0
#
#    COVID_NewRecovered  COVID_ActiveCases  COVID_Serious/Critical  \
# 0                 NaN          2292707.0                 18296.0
# 1                 NaN           771258.0                  8318.0
# ...

# %%
covid_data_df.head()
# Out:
#    Country_Name    Population  COVID_TotalCases  COVID_NewCases  \
# 0           USA  3.311981e+08           5032179             NaN
# 1        Brazil  2.127107e+08           2917562             NaN
# 2         India  1.381345e+09           2025409             NaN
# 3        Russia  1.459409e+08            871894             NaN
# 4  South Africa  5.938157e+07            538184             NaN
#
#    COVID_TotalDeaths  COVID_NewDeaths  COVID_TotalRecovered  \
# 0           162804.0              NaN             2576668.0
# 1            98644.0              NaN             2047660.0
# 2            41638.0              NaN             1377384.0
# 3            14606.0              NaN              676357.0
# 4             9604.0              NaN              387316.0
#
#    COVID_NewRecovered  COVID_ActiveCases  COVID_Serious/Critical  \
# 0                 NaN          2292707.0                 18296.0
# 1                 NaN           771258.0                  8318.0
# ...

# %%
happiness_scores_alchohol_covid_df = pd.merge(happiness_scores_alchohol,covid_data_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol_covid_df.head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol_covid_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                            71
# Regional_Indicator                              71
# Ladder_Score                                    71
# Logged_GDP_per_Capita                          107
# Social support                                  84
# Healthy_Life_Expectancy                        126
# Freedom_to_make_life_choices                   103
# Generosity                                     160
# Perceptions_of_corruption                      181
# Positive_Affect                                242
# Negative_affect                                236
# Standard error of ladder score                2020
# upperwhisker                                  2020
# lowerwhisker                                  2020
# Ladder score in Dystopia                      2020
# Explained by: Log GDP per capita              2020
# Explained by: Social support                  2020
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol_covid_df)
# Out:
# 2169

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_scores_alchohol_covid_df[~happiness_scores_alchohol_covid_df['COVID_TotalCases'].isnull()].head()
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# 4                  7.705           0.521                    52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  ...  \
# 0                         0.718       0.168                      0.882  ...
# ...

# %% [markdown]
# # Clean screen_time_df dataset

# %%
screen_time_df.head()
# Out:
#    Country_Name  Average_screen_time
# 0  South Africa                10.46
# 1   Philippines                10.27
# 2        Brazil                10.19
# 3      Colombia                10.03
# 4     Argentina                 9.38

# %%
#screen_time_df = screen_time_df.drop(columns="Country_Name")
#screen_time_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 screen_time_df = screen_time_df.drop(columns="Country_Source")
#       2 screen_time_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
# ...

# %%
#View all column names
list(screen_time_df)
# Out:
# ['Country_Name', 'Average_screen_time']

# %%
#rename columns
screen_time_df.rename(columns = {'Country_Clean': 'Country_Name'}, inplace = True)
screen_time_df.rename(columns = {'Average screen time': 'Average_screen_time'}, inplace = True)

# %%
screen_time_df.head()
# Out:
#    Country_Name  Average_screen_time
# 0  South Africa                10.46
# 1   Philippines                10.27
# 2        Brazil                10.19
# 3      Colombia                10.03
# 4     Argentina                 9.38

# %%
#combine datasets
happiness_scores_alchohol_covid__screen_df = pd.merge(happiness_scores_alchohol_covid_df,screen_time_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol_covid__screen_df.head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol_covid__screen_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                            71
# Regional_Indicator                              71
# Ladder_Score                                    71
# Logged_GDP_per_Capita                          107
# Social support                                  84
# Healthy_Life_Expectancy                        126
# Freedom_to_make_life_choices                   103
# Generosity                                     160
# Perceptions_of_corruption                      181
# Positive_Affect                                242
# Negative_affect                                236
# Standard error of ladder score                2020
# upperwhisker                                  2020
# lowerwhisker                                  2020
# Ladder score in Dystopia                      2020
# Explained by: Log GDP per capita              2020
# Explained by: Social support                  2020
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol_covid__screen_df)
# Out:
# 2169

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_scores_alchohol_covid__screen_df[~happiness_scores_alchohol_covid__screen_df['Average_screen_time'].isnull()].head(50)
# Out:
#     Country_Name    year           Regional_Indicator  Ladder_Score  \
# 40     Argentina  2006.0  Latin America and Caribbean         6.313
# 41     Argentina  2007.0  Latin America and Caribbean         6.073
# 42     Argentina  2008.0  Latin America and Caribbean         5.961
# 43     Argentina  2009.0  Latin America and Caribbean         6.424
# 44     Argentina  2010.0  Latin America and Caribbean         6.441
# 45     Argentina  2011.0  Latin America and Caribbean         6.776
# 46     Argentina  2012.0  Latin America and Caribbean         6.468
# 47     Argentina  2013.0  Latin America and Caribbean         6.582
# 48     Argentina  2014.0  Latin America and Caribbean         6.671
# 49     Argentina  2015.0  Latin America and Caribbean         6.697
# 50     Argentina  2016.0  Latin America and Caribbean         6.427
# 51     Argentina  2017.0  Latin America and Caribbean         6.039
# 52     Argentina  2018.0  Latin America and Caribbean         5.793
# ...

# %% [markdown]
# # Clean population_density_df dataframe

# %%
population_density_df.head()
# Out:
#   Country_Name Population_2020 Land_Area_Km Density_P/Km
# 0  Afghanistan      38,041,750      652,230        56.94
# 1      Albania       2,854,190       28,748       104.61
# 2      Algeria      43,053,050    2,381,740        17.73
# 3      Andorra          77,140          468       163.84
# 4       Angola      31,825,290    1,246,700        24.71

# %%
#View all column names
list(population_density_df)
# Out:
# ['Country_Name', 'Population_2020', 'Land_Area_Km', 'Density_P/Km']

# %%
#rename columns
population_density_df.rename(columns = {'Country': 'Country_Name'}, inplace = True)
population_density_df.rename(columns = {'Population (2020)': 'Population_2020'}, inplace = True)
population_density_df.rename(columns = {'Land Area (Km²)': 'Land_Area_Km'}, inplace = True)
population_density_df.rename(columns = {'Density (P/Km²)': 'Density_P/Km'}, inplace = True)

# %%
population_density_df.head()
# Out:
#   Country_Name Population_2020 Land_Area_Km Density_P/Km
# 0  Afghanistan      38,041,750      652,230        56.94
# 1      Albania       2,854,190       28,748       104.61
# 2      Algeria      43,053,050    2,381,740        17.73
# 3      Andorra          77,140          468       163.84
# 4       Angola      31,825,290    1,246,700        24.71

# %%
#combine datasets
happiness_scores_alchohol_covid__screen_density_df = pd.merge(happiness_scores_alchohol_covid__screen_df,population_density_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol_covid__screen_density_df.head()
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# 4                  7.705           0.521                    52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  ...  \
# 0                         0.718       0.168                      0.882  ...
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol_covid__screen_density_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                            79
# Regional_Indicator                              79
# Ladder_Score                                    79
# Logged_GDP_per_Capita                          115
# Social support                                  92
# Healthy_Life_Expectancy                        134
# Freedom_to_make_life_choices                   111
# Generosity                                     168
# Perceptions_of_corruption                      189
# Positive_Affect                                250
# Negative_affect                                244
# Standard error of ladder score                2028
# upperwhisker                                  2028
# lowerwhisker                                  2028
# Ladder score in Dystopia                      2028
# Explained by: Log GDP per capita              2028
# Explained by: Social support                  2028
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol_covid__screen_density_df)
# Out:
# 2177

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_scores_alchohol_covid__screen_density_df[~happiness_scores_alchohol_covid__screen_density_df['Density_P/Km'].isnull()].head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %% [markdown]
# # Clean meat_consumption_df dataframe

# %%
meat_consumption_df.head()
# Out:
#           Country_Name  Meat_Consumption
# 0          Afghanistan              17.3
# 1              Algeria              18.3
# 2       American Samoa              24.9
# 3               Angola              19.0
# 4  Antigua and Barbuda              56.0

# %%
#View all column names
list(meat_consumption_df)
# Out:
# ['Country_Name', 'Meat_Consumption']

# %%
#drop unwanted columns 
meat_consumption_df = meat_consumption_df.drop(columns="ISO-code")
meat_consumption_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       1 #drop unwanted columns
# ----> 2 meat_consumption_df = meat_consumption_df.drop(columns="ISO-code")
#       3 meat_consumption_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
# ...

# %%
#rename columns
meat_consumption_df.rename(columns = {'Country': 'Country_Name'}, inplace = True)
meat_consumption_df.rename(columns = {'Meat consumption': 'Meat_Consumption'}, inplace = True)

# %%
meat_consumption_df.head()
# Out:
#           Country_Name  Meat_Consumption
# 0          Afghanistan              17.3
# 1              Algeria              18.3
# 2       American Samoa              24.9
# 3               Angola              19.0
# 4  Antigua and Barbuda              56.0

# %%
#combine datasets
happiness_scores_alchohol_covid__screen_density_meat_df = pd.merge(happiness_scores_alchohol_covid__screen_density_df,meat_consumption_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol_covid__screen_density_meat_df.head()
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# 4                  7.705           0.521                    52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  ...  \
# 0                         0.718       0.168                      0.882  ...
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol_covid__screen_density_meat_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                            87
# Regional_Indicator                              87
# Ladder_Score                                    87
# Logged_GDP_per_Capita                          123
# Social support                                 100
# Healthy_Life_Expectancy                        142
# Freedom_to_make_life_choices                   119
# Generosity                                     176
# Perceptions_of_corruption                      198
# Positive_Affect                                259
# Negative_affect                                253
# Standard error of ladder score                2054
# upperwhisker                                  2054
# lowerwhisker                                  2054
# Ladder score in Dystopia                      2054
# Explained by: Log GDP per capita              2054
# Explained by: Social support                  2054
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol_covid__screen_density_meat_df)
# Out:
# 2204

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_scores_alchohol_covid__screen_density_meat_df[~happiness_scores_alchohol_covid__screen_density_meat_df['Meat_Consumption'].isnull()].head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %% [markdown]
# # Clean median_age_df dataset

# %%
median_age_df.head()
# Out:
#      Country_Name  Median_Age
# 0     Afghanistan        27.4
# 1         Albania        32.9
# 2         Algeria        28.1
# 3  American Samoa        25.5
# 4         Andorra        44.3

# %%
#View all column names
list(median_age_df)
# Out:
# ['Country_Name', 'Median_Age']

# %%
#drop unwanted columns 
median_age_df = median_age_df.drop(columns="ISO-code")
median_age_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 #drop unwanted columns
# ----> 2 median_age_df = median_age_df.drop(columns="ISO-code")
#       3 median_age_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
# ...

# %%
#rename columns
median_age_df.rename(columns = {'Country': 'Country_Name'}, inplace = True)
median_age_df.rename(columns = {'Median age': 'Median_Age'}, inplace = True)

# %%
median_age_df.head()
# Out:
#      Country_Name  Median_Age
# 0     Afghanistan        27.4
# 1         Albania        32.9
# 2         Algeria        28.1
# 3  American Samoa        25.5
# 4         Andorra        44.3

# %%
#combine datasets
happiness_scores_alchohol_covid__screen_density_meat_age_df = pd.merge(happiness_scores_alchohol_covid__screen_density_meat_df,median_age_df,on=['Country_Name'],how='outer')

# %%
happiness_scores_alchohol_covid__screen_density_meat_age_df.head()
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# 4                  7.705           0.521                    52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  ...  \
# 0                         0.718       0.168                      0.882  ...
# ...

# %%
#view NA counts for combined columns
happiness_scores_alchohol_covid__screen_density_meat_age_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                           102
# Regional_Indicator                             102
# Ladder_Score                                   102
# Logged_GDP_per_Capita                          138
# Social support                                 115
# Healthy_Life_Expectancy                        157
# Freedom_to_make_life_choices                   134
# Generosity                                     191
# Perceptions_of_corruption                      213
# Positive_Affect                                274
# Negative_affect                                268
# Standard error of ladder score                2069
# upperwhisker                                  2069
# lowerwhisker                                  2069
# Ladder score in Dystopia                      2069
# Explained by: Log GDP per capita              2069
# Explained by: Social support                  2069
# ...

# %%
#compare NA values to dataset row count
len(happiness_scores_alchohol_covid__screen_density_meat_age_df)
# Out:
# 2219

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_scores_alchohol_covid__screen_density_meat_age_df[~happiness_scores_alchohol_covid__screen_density_meat_age_df['Median_Age'].isnull()].head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %% [markdown]
# # clean suicide_rate_df dataframe

# %%
suicide_rate_df.head()
# Out:
#           Country_Name  Suicide_rate
# 0          Afghanistan           6.4
# 1              Albania           5.6
# 2              Algeria           3.3
# 3               Angola           8.9
# 4  Antigua and Barbuda           0.5

# %%
#View all column names
list(suicide_rate_df)
# Out:
# ['Country_Name', 'Suicide_rate']

# %%
#drop unwanted columns 
suicide_rate_df = suicide_rate_df.drop(columns="ISO-code")
suicide_rate_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [74], in <cell line: 2>()
#       1 #drop unwanted columns
# ----> 2 suicide_rate_df = suicide_rate_df.drop(columns="ISO-code")
#       3 suicide_rate_df.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
# ...

# %%
#rename columns
suicide_rate_df.rename(columns = {'Country': 'Country_Name'}, inplace = True)
suicide_rate_df.rename(columns = {'Suicide rate': 'Suicide_rate'}, inplace = True)

# %%
suicide_rate_df.head()
# Out:
#           Country_Name  Suicide_rate
# 0          Afghanistan           6.4
# 1              Albania           5.6
# 2              Algeria           3.3
# 3               Angola           8.9
# 4  Antigua and Barbuda           0.5

# %%
#combine datasets
happiness_data_all_df = pd.merge(happiness_scores_alchohol_covid__screen_density_meat_age_df,suicide_rate_df,on=['Country_Name'],how='outer')

# %%
happiness_data_all_df.head()
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# 4                  7.705           0.521                    52.24
#
#    Freedom_to_make_life_choices  Generosity  Perceptions_of_corruption  ...  \
# 0                         0.718       0.168                      0.882  ...
# ...

# %%
#view NA counts for combined columns
happiness_data_all_df.isna().sum()
# Out:
# Country_Name                                     0
# year                                           102
# Regional_Indicator                             102
# Ladder_Score                                   102
# Logged_GDP_per_Capita                          138
# Social support                                 115
# Healthy_Life_Expectancy                        157
# Freedom_to_make_life_choices                   134
# Generosity                                     191
# Perceptions_of_corruption                      215
# Positive_Affect                                276
# Negative_affect                                270
# Standard error of ladder score                2105
# upperwhisker                                  2105
# lowerwhisker                                  2105
# Ladder score in Dystopia                      2105
# Explained by: Log GDP per capita              2105
# Explained by: Social support                  2105
# ...

# %%
#compare NA values to dataset row count
len(happiness_data_all_df)
# Out:
# 2257

# %%
#View rows that have non-NA values for COVID to ensure join worked correctly 
happiness_data_all_df[~happiness_data_all_df['Suicide_rate'].isnull()].head(10)
# Out:
#   Country_Name    year Regional_Indicator  Ladder_Score  \
# 0  Afghanistan  2008.0         South Asia         3.724
# 1  Afghanistan  2009.0         South Asia         4.402
# 2  Afghanistan  2010.0         South Asia         4.758
# 3  Afghanistan  2011.0         South Asia         3.832
# 4  Afghanistan  2012.0         South Asia         3.783
# 5  Afghanistan  2013.0         South Asia         3.572
# 6  Afghanistan  2014.0         South Asia         3.131
# 7  Afghanistan  2015.0         South Asia         3.983
# 8  Afghanistan  2016.0         South Asia         4.220
# 9  Afghanistan  2017.0         South Asia         2.662
#
#    Logged_GDP_per_Capita  Social support  Healthy_Life_Expectancy  \
# 0                  7.370           0.451                    50.80
# 1                  7.540           0.552                    51.20
# 2                  7.647           0.539                    51.60
# 3                  7.620           0.521                    51.92
# ...

# %%
happiness_data_all_df.Country_Name.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti',
#        'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia',
#        'Ethiopia', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea', 'Guyana',
#        'Haiti', 'Honduras', 'Hong Kong S.A.R. of China', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#        'Israel', 'Italy', 'Ivory Coast', 'Jamaica', 'Japan', 'Jordan',
# ...

# %% [markdown]
# # Export Clean Dataset

# %%
#export DataFrame to CSV file
#happiness_t_file_df.to_csv('Data/world-happiness-report-clean.csv', index=False)

# %%
#export DataFrame to CSV file
#happiness_file_2021_df.to_csv('Data/world-happiness-report-2021-clean.csv', index=False)

# %%
#export DataFrame to CSV file
#alcohol_consumption_df.to_csv('Data/alcohol_consumption_bycountry-clean.csv', index=False)

# %%
#export DataFrame to CSV file
#covid_data_df.to_csv('Data/kaggle-covid/worldometer_data_clean.csv', index=False)

# %%
#export DataFrame to CSV file
#screen_time_df.to_csv('Data/Clean_Average_Screen_Time_per_Country_2021_clean.csv', index=False)

# %%
#export DataFrame to CSV file
#population_density_df.to_csv('Data/Country_Population_Land_Area_Density_clean.csv', index=False)

# %%
#export DataFrame to CSV file
#meat_consumption_df.to_csv('Data/Meat_consumption_clean.csv', index=False)

# %%
#export DataFrame to CSV file
#median_age_df.to_csv('Data/Median_age_clean.csv', index=False)

# %%
#export DataFrame to CSV file
#suicide_rate_df.to_csv('Data/Suicide_rate_clean.csv', index=False)
